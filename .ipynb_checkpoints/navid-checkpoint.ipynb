# %%
import pandas as pd
from fbprophet import Prophet

# %%
df = pd.read_csv('2019.csv')
df.head()
# Out:
#                  ds     y
# 0  1/01/19 01:00:00  4617
# 1  1/01/19 02:00:00  4437
# 2  1/01/19 03:00:00  4315
# 3  1/01/19 04:00:00  4207
# 4  1/01/19 05:00:00  4154

# %%
m = Prophet(yearly_seasonality=True)
m.fit(df)

# %%
#future=pd.read_csv('predict.csv')
future = m.make_future_dataframe(periods=24)
#future.head()

# %%
forecast = m.predict(future)
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#                       ds         yhat   yhat_lower   yhat_upper
# 8779 2020-01-20 23:00:00  5868.351647  5384.365073  6348.869822
# 8780 2020-01-21 23:00:00  5908.846853  5355.625546  6369.427962
# 8781 2020-01-22 23:00:00  5999.954156  5481.963370  6527.381937
# 8782 2020-01-23 23:00:00  5915.544226  5417.361783  6399.225641
# 8783 2020-01-24 23:00:00  5718.510695  5230.378875  6177.379952

# %%
forecast[['ds', 'yhat', 'yhat_lower', 'yhat_upper']].tail()
# Out:
#                       ds         yhat   yhat_lower   yhat_upper
# 8779 2020-01-20 23:00:00  5868.351647  5384.365073  6348.869822
# 8780 2020-01-21 23:00:00  5908.846853  5355.625546  6369.427962
# 8781 2020-01-22 23:00:00  5999.954156  5481.963370  6527.381937
# 8782 2020-01-23 23:00:00  5915.544226  5417.361783  6399.225641
# 8783 2020-01-24 23:00:00  5718.510695  5230.378875  6177.379952

# %%
fig1 = m.plot(forecast)

# %%
m.plot_components(forecast)
